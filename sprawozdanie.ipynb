# %% [markdown]
# # <center>Metody Numeryczne</center>
#
# # Laboratorium 8: Rozwiązywanie równań nieliniowych
#
#
# **Wykonał:** \<Piotr Gałązka\>
#
# <br>
#
# ### **Metoda zaliczenia:**
#
# Podczas zajęć należy wykonać poniższe polecenia oraz udzielić odpowiedzi na pytania zamieszczone w treści zadań.
#
# Wszystkie funkcje wymagane w ramach ćwiczenia należy zaimplementować w pliku `main.py`. Poprawność ich działania należy zweryfikować za pomocą testów jednostkowych dostępnych w pliku `test_main.py`.
#
# ### **Cel zajęć:**
#
# Celem zajęć jest poznanie numerycznych metod rozwiązywania układów równań nieliniowych. W ramach laboratorium przedstawione zostaną metody: [*bisekcji*](https://www.wikiwand.com/pl/articles/Metoda_r%C3%B3wnego_podzia%C5%82u), [*siecznych*](https://www.wikiwand.com/pl/articles/Metoda_siecznych) oraz [*Newtona*](https://www.wikiwand.com/pl/articles/Metoda_Newtona).
#
# Tematem wiodącym podczas tych zajęć będzie poszukiwanie miejsc zerowych funkcji zdefiniowanej w następujący sposób:
# $$
# f(x) = e^{-2x} + x^2 - 1
# $$
#
# Funkcja $f(x)$ oraz jej pierwsza i druga pochodna ($f'(x)$, $f''(x)$) zostały zaimplementowane w pliku `main.py`, odpowiednio jako `func()`, `dfunc()` i `ddfunc()`.
#
# ### **Uwagi wstępne:**
# - Funkcje wymagające implementacji (lub zaimplementowane na poprzednich laboratoriach) oznaczone są pochyłą czcionką maszynową (np. *`my_func()`*).
#
# - W skrypcie stosuje się następujące skróty:
#
#     - `np` - `numpy`,
#     - `sp` - `scipy`.

# %% [markdown]
# ---

# %%
# !python -m pip install numpy scipy matplotlib

import main

import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 1.**
#
# 1. Zaprezentuj na jednym wykresie przebieg funkcji $f(x)$, $f'(x)$ oraz $f''(x)$, w taki sposób, aby na podstawie rysunku można było zgrubnie określić położenie miejsc zerowych funkcji.
#
# 2. Na podstawie analizy wykresu określ przedziały, w których znajdują się miejsca zerowe funkcji $f(x)$.
#
# 3. Odpowiedz w jaki sposób (wykorzystując pierwszą i drugą pochodną) można znaleźć miejsca zerowe funkcji.

# %%
# ===== Twoja implementacja tutaj =====
x= np.linspace(-0.5,5,50)

plt.plot(x,main.func(x),label = 'f(x)')
plt.plot(x,main.dfunc(x),label = "f'(x)")
plt.plot(x,main.ddfunc(x),label = 'f"(x)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 2.**
#
# Najprostszą metodą do wyznaczenia miejsc zerowych funkcji nieliniowej jest [metoda bisekcji](https://en.wikipedia.org/wiki/Bisection_method).
#
# Zaimplementuj funkcję *`bisection()`* pamiętając, że gwarancją zbieżności metody bisekcji dla poszukiwania miejsca zerowego funkcji $f(x)$ na odcinku $[a,b]$ są następujące założenia:
#
# 1. Funkcja $f(x)$ jest ciągła w przedziale domkniętym $[a,b]$.
#
# 2. Funkcja $f(x)$ przyjmuje różne znaki na końcach przedziału: $f(a)f(b)<0$.

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 3.**
#
# Bardziej zaawansowaną metodą wyznaczania miejsc zerowych jest [metoda siecznych](https://en.wikipedia.org/wiki/Secant_method), która stanowi rozwinięcie [metody Regula Falsi](https://en.wikipedia.org/wiki/Regula_falsi).
#
# Zaimplementuj funkcję *`secant()`* pamiętając, że gwarancją zbieżności metody siecznych dla poszukiwania miejsca zerowego funkcji $f(x)$ na odcinku $[a,b]$ są następujące założenia:
#
# 1. Funkcja $f(x)$ jest ciągła w przedziale domkniętym $[a,b]$.
#
# 2. Funkcja $f(x)$ przyjmuje różne znaki na końcach przedziału: $f(a)f(b)<0$.
#
# 3. Pierwsza i druga pochodna funkcji $f(x)$ są ciągłe w przedziale domkniętym $[a,b]$.
#
# 4. Pierwsza i druga pochodna funkcji $f(x)$ w przedziale domkniętym $[a, b]$ mają stały znak i są różne od zera.

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 4.**
#
# Inną metodą, wykorzystywaną do poszukiwania miejsc zerowych funkcji, jest [metoda Newtona](https://en.wikipedia.org/wiki/Newton%27s_method), nazywana również metodą stycznych.
#
# **Podpunkt 1.**
#
# Algorytm metody Newtona wykorzystuje wartości pierwszej pochodnej, dlatego przed przystąpieniem do jej implementacji przygotuj pomocniczą funkcję *`difference_quotient()`*, służącą do wyznaczenia wartości ilorazu różnicowego.
#
# <br>
#
# **Podpunkt 2.**
#
# Zaimplementuj funkcję *`newton()`* pamiętając, że gwarancją zbieżności metody Newtona dla poszukiwania miejsca zerowego funkcji $f(x)$ na odcinku $[a,b]$ są następujące założenia:
#
# 1. Funkcja $f(x)$ jest ciągła w przedziale domkniętym $[a,b]$.
#
# 2. Funkcja $f(x)$ przyjmuje różne znaki na końcach przedziału: $f(a)f(b)<0$.
#
# 3. Pierwsza i druga pochodna funkcji $f(x)$ są ciągłe w przedziale domkniętym $[a,b]$.
#
# 4. Pierwsza i druga pochodna funkcji $f(x)$ w przedziale domkniętym $[a, b]$ mają stały znak i są różne od zera.

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 5.**
#
# Dla funkcji $f(x)$ zdefiniowanej w sekcji **Cel zajęć** znajdź miejsca zerowe przy użyciu:
#
# - funkcji [`sp.optimize.root()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.root.html).
# - funkcji [`sp.optimize.fsolve()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fsolve.html).

# %%
# ===== Twoja implementacja tutaj =====
mz1 = sp.optimize.root(main.func,0.9)
mz2 = sp.optimize.fsolve(main.func,0.9)
print("rozw przy pomocy sp.optimize.roo = ", mz1.x)
print("rozw przy pomocy sp.optimize.fsolve = ",mz2)
# Out:
# rozw przy pomocy sp.optimize.roo =  [0.91656258]
# rozw przy pomocy sp.optimize.fsolve =  [0.91656258]

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 6.**
#
# Korzystając z przedziałów wyznaczonych w **Zadaniu 1.** znajdź miejsca zerowe funkcji $f(x)$ zdefiniowanej w sekcji **Cel zajęć**, przy użyciu:
#
# - metody bisekcji,
# - metody siecznych,
# - metody Newtona,
#
# z tolerancją równą $1\mathrm{e}{-10}$.
#
# Zbadaj dokładność (względem rozwiązania z **Zadania 5.**) i czas obliczeń metod w zależności od liczby iteracji. Wyniki przedstaw na wykresach.

# %%
# ===== Twoja implementacja tutaj =====
a = 0.8
b = 1
epsilon = 1e-10
max_iter_tablica = np.linspace(2,50,20)

time_bisekcja = []
time_sieczna = []
time_Newton = []

roznica_bisekcja = []
roznica_sieczna = []
roznica_Newton = []

for max_iter_float in max_iter_tablica:
    max_iter = int(max_iter_float)
    mz_bisekcja, _ = main.bisection(a,b,main.func,epsilon,max_iter)
    mz_sieczne, _ = main.secant(a,b,main.func,epsilon,max_iter)
    mz_Newton, _ = main.newton(main.func,main.dfunc,main.ddfunc,a,b,epsilon,max_iter) 

    time_b = %timeit -r 3 -n 3 -o (main.bisection(a,b,main.func,epsilon,max_iter) )
    time_s = %timeit -r 3 -n 3 -o (main.secant(a,b,main.func,epsilon,max_iter)) 
    time_N = %timeit -r 3 -n 3 -o (main.newton(main.func,main.dfunc,main.ddfunc,a,b,epsilon,max_iter)) 

    time_bisekcja.append(time_b.best)
    time_sieczna.append(time_s.best)
    time_Newton.append(time_N.best)

    roznica_bisekcja.append(np.abs(mz_bisekcja - mz2))
    roznica_sieczna.append(np.abs(mz_sieczne - mz2))
    roznica_Newton.append(np.abs(mz_Newton - mz2))


plt.plot(max_iter_tablica, time_bisekcja, label = 'bisekcja')
plt.plot(max_iter_tablica, time_sieczna, label = 'sieczna')
plt.plot(max_iter_tablica, time_Newton, label = 'Newton')

plt.legend()
plt.title("Czas wykonania")
plt.yscale('log')
plt.show()


plt.plot(max_iter_tablica, roznica_bisekcja, label = 'bisekcja')
plt.plot(max_iter_tablica, roznica_sieczna, label = 'sieczna')
plt.plot(max_iter_tablica, roznica_Newton, label = 'Newton')

plt.legend()
plt.title("Błąd względem wzorcowego wyniku")
plt.yscale('log')
plt.show()
# Out:
# 33.9 μs ± 2.33 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 25.4 μs ± 2.8 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 31.1 μs ± 1.96 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 46.8 μs ± 1.16 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 38 μs ± 1.77 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 45.9 μs ± 4.85 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 67.6 μs ± 778 ns per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 86.2 μs ± 40.4 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.4 μs ± 1.94 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 81.2 μs ± 2.49 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.9 μs ± 1.79 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.8 μs ± 2.68 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 100 μs ± 2.29 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.7 μs ± 1.67 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.2 μs ± 1.62 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 112 μs ± 1.52 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.1 μs ± 2.63 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41 μs ± 1.77 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 132 μs ± 1.52 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.8 μs ± 1.88 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 40.7 μs ± 1.55 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 153 μs ± 7.81 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.1 μs ± 2.95 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41 μs ± 2.01 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 168 μs ± 1.82 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.5 μs ± 2.77 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.1 μs ± 1.92 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 182 μs ± 2.27 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.5 μs ± 3.22 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.4 μs ± 2.09 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 203 μs ± 8.76 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.6 μs ± 1.57 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41 μs ± 1.9 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 210 μs ± 2.61 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.8 μs ± 1.89 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.5 μs ± 1.36 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 208 μs ± 87.5 ns per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.5 μs ± 1.78 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.7 μs ± 1.76 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 210 μs ± 1.73 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.8 μs ± 2.2 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 40.7 μs ± 1.56 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 227 μs ± 17.7 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.6 μs ± 1.68 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 40.8 μs ± 1.6 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 215 μs ± 9.15 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.6 μs ± 2.21 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41 μs ± 1.82 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 210 μs ± 1.37 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 65.5 μs ± 1.76 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.3 μs ± 1.65 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 207 μs ± 1.22 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.6 μs ± 1.7 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41 μs ± 1.55 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 208 μs ± 1.72 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 64.4 μs ± 1.66 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41.1 μs ± 2.02 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 208 μs ± 1.35 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 63.6 μs ± 2.02 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 41 μs ± 1.78 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)

# %% [markdown]
# ---

# %% [markdown]
# **Materiały uzupełniające:**
# - [Scipy Lecture Notes](http://www.scipy-lectures.org/index.html)
# - [NumPy for Matlab users](https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html#numpy-for-matlab-users)
# - [Python Tutorial - W3Schools](https://www.w3schools.com/python/default.asp)
# - [NumPy](https://www.numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Anaconda](https://www.anaconda.com/)
# - [Learn Python for Data Science](https://www.datacamp.com/learn-python-with-anaconda?utm_source=Anaconda_download&utm_campaign=datacamp_training&utm_medium=banner)
# - [Learn Python](https://www.learnpython.org/)
# - [Wujek Google](https://google.pl) i [Ciocia Wikipedia](https://pl.wikipedia.org/wiki/Wikipedia:Strona_g%C5%82%C3%B3wna)
